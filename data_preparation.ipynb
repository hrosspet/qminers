# %% [markdown]
# # Load and prepare data

# %%
import os
from google.colab import drive

drive.mount('/content/gdrive')
os.chdir('gdrive/My Drive/home/qminers')
# Out:
# Mounted at /content/gdrive

# %%
import matplotlib.pyplot as plt
import pandas as pd
from qminers.utils import prepare_data_v1

prepare_data = prepare_data_v1

# %%
financial_df = pd.read_csv('data/sp500_2010_01_01-2014_07_31.csv')
calendar_df = pd.read_csv('data/econ_calendar.csv')

data_train_val, data_test = prepare_data(financial_df, calendar_df)

# %%
data_train_val.head()
# Out:
#                   Open        High         Low       Close  Adj Close  \
# Date
# 2010-01-04  112.370003  113.389999  111.510002  113.330002  94.545494
# 2010-01-05  113.260002  113.680000  112.849998  113.629997  94.795784
# 2010-01-06  113.519997  113.989998  113.430000  113.709999  94.862526
# 2010-01-07  113.500000  114.330002  113.180000  114.190002  95.262955
# 2010-01-08  113.889999  114.620003  113.660004  114.570000  95.579971
#
#             High Impact Expected  Low Impact Expected  Medium Impact Expected  \
# Date
# 2010-01-04                     6                   33                      15
# 2010-01-05                     6                   15                      27
# 2010-01-06                    21                   21                      12
# 2010-01-07                    18                    9                      21
# 2010-01-08                    10                   20                      10
#
#             Non-Economic     Volume
# Date
# 2010-01-04             0  118944600
# 2010-01-05             0  111579900
# 2010-01-06             3  116074400
# 2010-01-07             0  131091100
# 2010-01-08             0  126402800

# %%
save_data(data_train_val, data_test, version='v1')
# Out:
# data saved to data/v1

# %%
# !git add eda.ipynb

# %%
# !git status
